# %%
# imports
from main import predict_word
# Out:
# => Starting training
# Loss: 3.06480419921875, Epoch: 50
# A$|Poyaiei
# onti
# ioatmbeatridaliaitnmnee
# roaiztuzmicltoacevod
# igc-ritiritlvgosi
# gia
# ivnolnteaisiecetfis
# ruiiomyt
# itauit
# ikPbesti
# r
# tnfrcsoteceos
# ziteopizs
# udetothz
# vezoinosi
# aeyttiszdniteinoitoxiiy
# Ahcr
# Loss: 2.679445556640625, Epoch: 100
# Ahys
# paimc
# hinet
# ]opntow
# nlnge
# waloic
# rosry
# dyrimar
# pocogooeton
# nci
# ghipinrerocclroroBi-g
# tuseres
# concoBtacoolmin
# anis
# caucatposr
# orargan
# leacutoulc
# sie
# arich
# oboaaryar
# nrinhragacy
# utobinstes
# clleDd
# sa
# Loss: 2.47433349609375, Epoch: 150
# Amarber
# ton-ranunetirz
# bhaashataitoticagorh-coni
# eagdinad
# datalmeth
# utetetotin
# Tasedocotis
# pisrelingt
# bpitgecorinne
# esijisisa
# unbergablanida
# xonatinciom
# usirevtalih
# rolal
# nadtesd
# rurholosrfifhaga
# bused
# Loss: 2.896351806640625, Epoch: 200
# Ady
# plarim
# sunuce
# fian
# -ispeated
# saroribubed
# molosBiocerimin
# rhryrilisariorg
# irevimohe
# ...

# %%
predict_word('A')
# Out:
# 'Agneate'
